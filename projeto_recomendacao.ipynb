# %%
# !pip install scikit-surprise
# !pip install dash
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-surprise in c:\programdata\anaconda3\lib\site-packages (1.1.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-surprise) (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\programdata\anaconda3\lib\site-packages (from scikit-surprise) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-surprise) (1.13.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: dash in c:\users\pc\appdata\roaming\python\python312\site-packages (2.18.1)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\pc\appdata\roaming\python\python312\site-packages (from dash) (2.3.3)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\pc\appdata\roaming\python\python312\site-packages (from dash) (3.0.6)
# Requirement already satisfied: plotly>=5.0.0 in c:\programdata\anaconda3\lib\site-packages (from dash) (5.22.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\pc\appdata\roaming\python\python312\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\pc\appdata\roaming\python\python312\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\pc\appdata\roaming\python\python312\site-packages (from dash) (5.0.0)
# Requirement already satisfied: importlib-metadata in c:\programdata\anaconda3\lib\site-packages (from dash) (7.0.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\programdata\anaconda3\lib\site-packages (from dash) (4.11.0)
# Requirement already satisfied: requests in c:\users\pc\appdata\roaming\python\python312\site-packages (from dash) (2.28.2)
# Requirement already satisfied: retrying in c:\users\pc\appdata\roaming\python\python312\site-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\programdata\anaconda3\lib\site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\pc\appdata\roaming\python\python312\site-packages (from dash) (75.8.2)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\pc\appdata\roaming\python\python312\site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\pc\appdata\roaming\python\python312\site-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\pc\appdata\roaming\python\python312\site-packages (from Flask<3.1,>=1.0.4->dash) (8.2.1)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\pc\appdata\roaming\python\python312\site-packages (from Flask<3.1,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\pc\appdata\roaming\python\python312\site-packages (from Werkzeug<3.1->dash) (2.1.5)
# Requirement already satisfied: colorama in c:\users\pc\appdata\roaming\python\python312\site-packages (from click>=8.1.3->Flask<3.1,>=1.0.4->dash) (0.4.6)
# Requirement already satisfied: tenacity>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (8.2.2)
# Requirement already satisfied: packaging in c:\users\pc\appdata\roaming\python\python312\site-packages (from plotly>=5.0.0->dash) (25.0)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata->dash) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pc\appdata\roaming\python\python312\site-packages (from requests->dash) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pc\appdata\roaming\python\python312\site-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\pc\appdata\roaming\python\python312\site-packages (from requests->dash) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pc\appdata\roaming\python\python312\site-packages (from requests->dash) (2025.7.14)
# Requirement already satisfied: six>=1.7.0 in c:\programdata\anaconda3\lib\site-packages (from retrying->dash) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\programdata\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import dash
import pandas as pd 
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances
from scipy.sparse import csr_matrix
import numpy as np
from surprise import Dataset, Reader, SVD as SurpriseSVD, accuracy
from surprise.model_selection import train_test_split
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_6100\636101105.py:3: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# C:\Users\pc\AppData\Local\Temp\ipykernel_6100\636101105.py:4: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %%
ratings = pd.read_csv('ratings.csv')  # Assumindo um arquivo ratings.csv com colunas userId, movieId e rating
movies = pd.read_csv('movies.csv')    # Assumindo um arquivo movies.csv com colunas movieId e title

# %%
ratings = ratings.drop_duplicates()
ratings['userId'] = ratings['userId'].astype(int)
ratings['movieId'] = ratings['movieId'].astype(int)
ratings['rating'] = ratings['rating'].astype(float)

# Cortando 30% dos dados (mantendo 70%)
ratings_sample = ratings.sample(frac=0.7, random_state=42)

# Tratamento de dados para movies
movies = movies.drop_duplicates()
movies['movieId'] = movies['movieId'].astype(int)
movies['title'] = movies['title'].astype(str)

# Cortando 30% dos dados (mantendo 70%)
movies_sample = movies.sample(frac=0.7, random_state=42)

# Confirmar alterações
print("Tamanho original de ratings:", ratings.shape)
print("Tamanho reduzido de ratings:", ratings_sample.shape)

print("\nTamanho original de movies:", movies.shape)
print("Tamanho reduzido de movies:", movies_sample.shape)
# Out:
# Tamanho original de ratings: (32000204, 4)
# Tamanho reduzido de ratings: (22400143, 4)
#
# Tamanho original de movies: (87585, 3)
# Tamanho reduzido de movies: (61309, 3)

# %%
# Amostragem de uma fração pequena de usuários e filmes
unique_users = ratings['userId'].drop_duplicates().sample(n=100, random_state=42)  # Limitando a 100 usuários
unique_movies = ratings['movieId'].drop_duplicates().sample(n=100, random_state=42)  # Limitando a 100 filmes

# Filtrando ratings por esses usuários e filmes amostrados
ratings_sample = ratings[ratings['userId'].isin(unique_users) & ratings['movieId'].isin(unique_movies)]

# Criando a matriz de usuários e filmes
ratings_matrix = ratings_sample.pivot(index='userId', columns='movieId', values='rating').fillna(0)

# Aplicando SVD com 1 componente
svd = TruncatedSVD(n_components=1, random_state=42)
matrix_svd = svd.fit_transform(ratings_matrix)

# Exibindo informações da matriz SVD
print("Forma da matriz SVD:", matrix_svd.shape)
# Out:
# Forma da matriz SVD: (20, 1)

# %%
from sklearn.decomposition import NMF

# Aplicando NMF com 1 componente
nmf = NMF(n_components=1, random_state=42)
matrix_nmf = nmf.fit_transform(ratings_matrix)

# Exibindo informações da matriz NMF
print("Forma da matriz NMF:", matrix_nmf.shape)
# Out:
# Forma da matriz NMF: (20, 1)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\decomposition\_nmf.py:1770: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(

# %%
# Supondo que você já tenha o dataframe `movies` carregado
# Exemplo: movies = pd.read_csv('movies.csv')

# Mesclando 'ratings' com 'movies' para obter o nome dos filmes
ratings_with_titles = ratings.merge(movies[['movieId', 'title']], on='movieId')

# Calculando a média dos ratings por filme (agrupando pelo nome do filme)
average_ratings = ratings_with_titles.groupby('title')['rating'].mean()

# Selecionando os 10 filmes com as maiores médias de rating
top_movies = average_ratings.nlargest(10).reset_index()

# Melhorando a saída do print (sem índice)
print("Top 10 filmes com as maiores médias de rating:\n")
print("{:<50} {:<10}".format("Filme", "Média de Rating"))
print("="*60)
for _, row in top_movies.iterrows():  # O _ ignora o índice
    print("{:<50} {:.2f}".format(row['title'], row['rating']))
# Out:
# Top 10 filmes com as maiores médias de rating:
#
# Filme                                              Média de Rating
# ============================================================
# $uperthief: Inside America's Biggest Bank Score (2012) 5.00
# 'Tis the Season to be Merry (2021)                 5.00
# 1 Message (2011)                                   5.00
# 11 September Vragen (2016)                         5.00
# 12 Dog Days Till Christmas (2014)                  5.00
# 1500 Steps (2014)                                  5.00
# 1964: Brazil Between Weapons and Books (2019)      5.00
# 1984 Revolution (2011)                             5.00
# 2 (2007)                                           5.00
# 2 Years of Love (2016)                             5.00

# %%
# Mesclando 'ratings' com 'movies' para obter os nomes dos filmes
ratings_with_titles = ratings.merge(movies[['movieId', 'title']], on='movieId')

# Contando o número de ratings por filme
popularity = ratings_with_titles.groupby('title')['rating'].count()

# Ordenando por popularidade (número de ratings) e exibindo os 10 mais populares
top_popular_movies = popularity.nlargest(10)
print("Top 10 filmes mais populares:")
for title, count in top_popular_movies.items():
    print(f"{title}: {count} ratings")
# Out:
# Top 10 filmes mais populares:
# Shawshank Redemption, The (1994): 102929 ratings
# Forrest Gump (1994): 100296 ratings
# Pulp Fiction (1994): 98409 ratings
# Matrix, The (1999): 93808 ratings
# Silence of the Lambs, The (1991): 90330 ratings
# Star Wars: Episode IV - A New Hope (1977): 85010 ratings
# Fight Club (1999): 77332 ratings
# Jurassic Park (1993): 75233 ratings
# Schindler's List (1993): 73849 ratings
# Lord of the Rings: The Fellowship of the Ring, The (2001): 73122 ratings

# %%
## Exemplo de filme escolhido
chosen_movie = "Toy Story (1995)"

# Verifique se o filme escolhido existe no DataFrame
if chosen_movie in movies['title'].values:
    # Selecionando o filme escolhido
    chosen_movie_genres = movies.loc[movies['title'] == chosen_movie, 'genres'].values[0]

    # Extraindo os gêneros do filme escolhido
    chosen_genres = set(chosen_movie_genres.split('|'))

    # Filtrando os filmes que compartilham ao menos um gênero com o filme escolhido
    movies_with_similar_genres = movies[movies['genres'].apply(lambda x: len(set(x.split('|')).intersection(chosen_genres)) > 0)]

    # Extraindo os gêneros e criando colunas binárias para cada gênero
    genres_matrix = movies_with_similar_genres['genres'].str.get_dummies(sep='|')

    # Criando uma matriz de filmes e gêneros
    movies_genre_matrix = pd.concat([movies_with_similar_genres[['movieId']], genres_matrix], axis=1).set_index('movieId')

    # Aplicando SVD com 2 componentes
    svd = TruncatedSVD(n_components=2, random_state=42)
    matrix_svd = svd.fit_transform(movies_genre_matrix)

    # Convertendo para DataFrame para fácil manipulação
    svd_df = pd.DataFrame(matrix_svd, index=movies_genre_matrix.index, columns=[f'Component {i+1}' for i in range(2)])

    # Exibindo a forma da matriz SVD
    print("Forma da matriz SVD:", svd_df.shape)

    # Visualizando a redução de dimensionalidade
    plt.figure(figsize=(10, 6))
    plt.scatter(svd_df['Component 1'], svd_df['Component 2'], alpha=0.5)

    # Destacando o filme escolhido
    chosen_movie_id = movies.loc[movies['title'] == chosen_movie, 'movieId'].values[0]
    plt.scatter(svd_df.loc[chosen_movie_id, 'Component 1'], svd_df.loc[chosen_movie_id, 'Component 2'], color='red', label=chosen_movie, s=100)

    plt.title('Redução de Dimensionalidade com SVD (Baseado em Gêneros)')
    plt.xlabel('Componente 1')
    plt.ylabel('Componente 2')
    plt.grid(True)
    plt.legend()
    plt.show()

else:
    print(f"O filme '{chosen_movie}' não foi encontrado no DataFrame.")

# Função para recomendar filmes
def recommend_movies_by_genre(movie_title, n_recommendations=5):
    # Obter o gênero do filme escolhido
    chosen_movie_genres = movies[movies['title'].str.contains(movie_title, case=False, na=False)]['genres'].values
    if len(chosen_movie_genres) == 0:
        print(f"Erro: O filme '{movie_title}' não foi encontrado.")
        return pd.Series([])

    chosen_movie_genres = chosen_movie_genres[0].split('|')  # Quebrar os gêneros em uma lista
    
    # Função auxiliar para contar gêneros em comum
    def genre_similarity(genres):
        movie_genres = genres.split('|')
        return len(set(movie_genres).intersection(set(chosen_movie_genres)))
    
    # Adicionar uma nova coluna para contar quantos gêneros em comum os filmes têm com o escolhido
    movies['similarity_score'] = movies['genres'].apply(genre_similarity)
    
    # Ordenar os filmes pela pontuação de similaridade e filtrar o filme escolhido
    recommended_movies = movies[movies['title'] != movie_title].sort_values(by='similarity_score', ascending=False)

    # Retornar os filmes mais similares
    return recommended_movies[['title', 'genres']].head(n_recommendations)

# Exemplo de recomendação
chosen_movie2 = "Pulp Fiction"  # Exemplo de filme
recommended = recommend_movies_by_genre(chosen_movie2, n_recommendations=100)

# Exibindo as recomendações
print(f"\nRecomendações baseadas nos gêneros de '{chosen_movie}':")
for idx, row in recommended.iterrows():
    print(f"- {row['title']} (Gêneros: {row['genres']})")
# Out:
# Forma da matriz SVD: (32406, 2)
# Recomendações baseadas nos gêneros de 'Toy Story (1995)':
# - Under Construction (2003) (Gêneros: Comedy|Crime|Drama|Thriller)
# - Dear Mr. Gacy (2010) (Gêneros: Comedy|Crime|Drama|Horror|Thriller)
# - Bad Boys (1995) (Gêneros: Action|Comedy|Crime|Drama|Thriller)
# - Godspeed (2016) (Gêneros: Comedy|Crime|Drama|Thriller)
# - Don (1978) (Gêneros: Action|Comedy|Crime|Drama|Musical|Thriller)
# - Leaves of Grass (2009) (Gêneros: Comedy|Crime|Drama|Thriller)
# - Body Count (1998) (Gêneros: Comedy|Crime|Drama|Thriller)
# - The 39 Steps (1959) (Gêneros: Action|Adventure|Comedy|Crime|Drama|Thriller)
# - Freeway II: Confessions of a Trickbaby (1999) (Gêneros: Comedy|Crime|Drama|Thriller)
# - Tiger's Tail, The (2006) (Gêneros: Comedy|Crime|Drama|Mystery|Thriller)
# - Pulp Fiction (1994) (Gêneros: Comedy|Crime|Drama|Thriller)
# - Ichi the Killer (Koroshiya 1) (2001) (Gêneros: Action|Comedy|Crime|Drama|Horror|Thriller)
# - Suicide Kings (1997) (Gêneros: Comedy|Crime|Drama|Mystery|Thriller)
# - Hard Word, The (2002) (Gêneros: Comedy|Crime|Drama|Thriller)
# - Dirty Weekend (1973) (Gêneros: Comedy|Crime|Drama|Thriller)
# - Business, The (2005) (Gêneros: Action|Comedy|Crime|Drama|Thriller)
# - Freeway (1996) (Gêneros: Comedy|Crime|Drama|Thriller)
# - Dead or Alive: Final (2002) (Gêneros: Comedy|Crime|Drama|Sci-Fi|Thriller)
# - Docks of New Orleans (1948) (Gêneros: Comedy|Crime|Drama|Mystery|Thriller)
# - Spreading Darkness (2017) (Gêneros: Comedy|Crime|Drama|Fantasy|Mystery|Thriller)
# - The Wrecking Crew (1968) (Gêneros: Action|Adventure|Comedy|Crime|Drama|Thriller)
# - Once Upon a Time (2008) (Gêneros: Action|Adventure|Comedy|Crime|Drama|Romance|Thriller)
# - Black Magic (1944) (Gêneros: Comedy|Crime|Drama|Horror|Mystery|Thriller)
# - Man Bites Dog (C'est arrivé près de chez vous) (1992) (Gêneros: Comedy|Crime|Drama|Thriller)
# - Longshot (2001) (Gêneros: Action|Comedy|Crime|Drama|Romance|Thriller)
# - Wasabi (2001) (Gêneros: Action|Comedy|Crime|Drama|Thriller)
# - Max & Jeremie (1992) (Gêneros: Comedy|Crime|Drama|Thriller)
# - Beautiful Creatures (2000) (Gêneros: Comedy|Crime|Drama|Thriller)
# - Nobel Son (2007) (Gêneros: Comedy|Crime|Drama|Thriller)
# - Informant!, The (2009) (Gêneros: Comedy|Crime|Drama|Thriller)
# - Osmosis Jones (2001) (Gêneros: Action|Animation|Comedy|Crime|Drama|Romance|Thriller)
# - Another 48 Hrs. (1990) (Gêneros: Action|Comedy|Crime|Drama|Thriller)
# - Charlie Chan in Panama (1940) (Gêneros: Adventure|Comedy|Crime|Drama|Mystery|Thriller)
# - Cul-de-sac (1966) (Gêneros: Comedy|Crime|Drama|Thriller)
# - The Lone Wolf Strikes (1940) (Gêneros: Comedy|Crime|Drama|Romance|Thriller)
# - Confessions of a Dangerous Mind (2002) (Gêneros: Comedy|Crime|Drama|Romance|Thriller)
# - Party Monster (2003) (Gêneros: Comedy|Crime|Drama|Thriller)
# - Under New Management (2009) (Gêneros: Action|Comedy|Crime|Drama|Romance|Thriller)
# - Black Shampoo (1976) (Gêneros: Action|Comedy|Crime|Drama|Thriller)
# - Nurse Betty (2000) (Gêneros: Comedy|Crime|Drama|Romance|Thriller)
# - Murder at the Gallop (1963) (Gêneros: Comedy|Crime|Drama|Mystery|Thriller)
# - Raffles (1939) (Gêneros: Adventure|Comedy|Crime|Drama|Romance|Thriller)
# - The Investigator (2008) (Gêneros: Comedy|Crime|Drama|Thriller)
# - Fifth Commandment, The (2008) (Gêneros: Action|Comedy|Crime|Drama|Thriller)
# - Murder Most Foul (1964) (Gêneros: Comedy|Crime|Drama|Mystery|Thriller)
# - Charlie Chan in Paris (1935) (Gêneros: Comedy|Crime|Drama|Mystery|Thriller)
# - Motorama (1991) (Gêneros: Adventure|Comedy|Crime|Drama|Fantasy|Mystery|Sci-Fi|Thriller)
# - Charlie Chan in Reno (1939) (Gêneros: Comedy|Crime|Drama|Mystery|Thriller)
# - Confessions of a Dangerous Mind (2002) (Gêneros: Comedy|Crime|Drama|Thriller)
# - Knives Out (2019) (Gêneros: Comedy|Crime|Drama|Mystery|Thriller)
# - Uncut Gems (2019) (Gêneros: Comedy|Crime|Drama|Thriller)
# - Fargo (1996) (Gêneros: Comedy|Crime|Drama|Thriller)
# - Killa Season (2006) (Gêneros: Comedy|Crime|Drama|Thriller)
# - Executive Koala (2005) (Gêneros: Comedy|Crime|Drama|Thriller)
# - Dead Men Tell (1941) (Gêneros: Comedy|Crime|Drama|Mystery|Thriller)
# - His Kind of Woman (1951) (Gêneros: Comedy|Crime|Drama|Film-Noir|Thriller)
# - Out of Sight (1998) (Gêneros: Comedy|Crime|Drama|Romance|Thriller)
# - The Blonde from Peking (1967) (Gêneros: Comedy|Crime|Drama|Thriller)
# - Klepto (2003) (Gêneros: Comedy|Crime|Drama|Thriller)
# - Metro (1997) (Gêneros: Action|Comedy|Crime|Drama|Thriller)
# - Schoolgirl Hitchhikers (1973) (Gêneros: Comedy|Crime|Drama|Thriller)
# - 11:14 (2003) (Gêneros: Comedy|Crime|Drama|Mystery|Thriller)
# - Rajathandhiram (2015) (Gêneros: Comedy|Crime|Drama|Romance|Thriller)
# - Super Cops, The (1974) (Gêneros: Action|Comedy|Crime|Drama|Thriller)
# - Breaking News in Yuba County (2021) (Gêneros: Comedy|Crime|Drama|Thriller)
# - Seven-Per-Cent Solution, The (1976) (Gêneros: Adventure|Comedy|Crime|Drama|Mystery|Thriller)
# - Fingers (2019) (Gêneros: Comedy|Crime|Drama|Horror|Thriller)
# - Under the Silver Lake (2018) (Gêneros: Comedy|Crime|Drama|Mystery|Thriller)
# - In Bruges (2008) (Gêneros: Comedy|Crime|Drama|Thriller)
# - Moving Violation (1976) (Gêneros: Comedy|Crime|Drama|Thriller)
# - Money Train (1995) (Gêneros: Action|Comedy|Crime|Drama|Thriller)
# - I Love Maria (1988) (Gêneros: Action|Comedy|Crime|Drama|Sci-Fi|Thriller)
# - Last Boy Scout, The (1991) (Gêneros: Action|Comedy|Crime|Drama|Thriller)
# - Rubber (2010) (Gêneros: Action|Adventure|Comedy|Crime|Drama|Film-Noir|Horror|Mystery|Thriller|Western)
# - The Crucifer of Blood (1991) (Gêneros: Comedy|Crime|Drama|Mystery|Thriller)
# - Svidd Neger (2003) (Gêneros: Comedy|Crime|Drama|Horror|Mystery|Romance|Thriller)
# - Lowlife (2017) (Gêneros: Action|Crime|Drama|Thriller)
# - Up the River (1930) (Gêneros: Comedy|Crime|Drama)
# - Goodbye Lover (1999) (Gêneros: Comedy|Crime|Thriller)
# - Good Luck Jerry (2022) (Gêneros: Comedy|Crime|Drama)
# - The Policemen and the Thieves (1997) (Gêneros: Comedy|Crime|Drama)
# - Snowflake (2017) (Gêneros: Action|Comedy|Crime|Fantasy|Thriller)
# - Double Jeopardy (1999) (Gêneros: Action|Crime|Drama|Thriller)
# - Octopus, The (Le poulpe) (1998) (Gêneros: Comedy|Crime|Thriller)
# - Joe + Belle (2011) (Gêneros: Comedy|Crime|Drama|Romance)
# - Life (1999) (Gêneros: Comedy|Crime|Drama)
# - Gone (2006) (Gêneros: Crime|Drama|Horror|Mystery|Thriller)
# - Visitors, The (1972) (Gêneros: Crime|Drama|Thriller)
# - Bitch (2017) (Gêneros: Children|Comedy|Drama|Thriller)
# - Dog Day (Canicule) (1984) (Gêneros: Action|Crime|Drama|Thriller)
# - Reservoir Cats (2011) (Gêneros: Comedy|Crime|Drama)
# - Behind the High Wall (1956) (Gêneros: Crime|Drama|Thriller)
# - The Finger Points (1931) (Gêneros: Crime|Drama|Thriller)
# - Postman Always Rings Twice, The (1946) (Gêneros: Crime|Drama|Film-Noir|Thriller)
# - True Blue (2001)  (Gêneros: Crime|Drama|Thriller)
# - Cry Wolf (1947) (Gêneros: Crime|Drama|Mystery|Thriller)
# - Cherry, Harry & Raquel! (1970) (Gêneros: Crime|Drama|Thriller)
# - Hi, Nellie! (1934) (Gêneros: Comedy|Crime|Drama)
# - Dream Lover (1986) (Gêneros: Crime|Drama|Thriller)
# - I Woke Up Early the Day I Died (1998) (Gêneros: Comedy|Crime|Thriller)

# %%
chosen_movie = "Toy Story (1995)"
#chosen_movie = "11 September Vragen (2016)"
#chosen_movie = "2 Years of Love (2016)"

# Verifique se o filme escolhido existe no DataFrame
if chosen_movie in movies['title'].values:
    # Selecionando o filme escolhido
    chosen_movie_genres = movies.loc[movies['title'] == chosen_movie, 'genres'].values[0]

    # Extraindo os gêneros do filme escolhido
    chosen_genres = set(chosen_movie_genres.split('|'))

    # Filtrando os filmes que compartilham ao menos um gênero com o filme escolhido
    movies_with_similar_genres = movies[movies['genres'].apply(lambda x: len(set(x.split('|')).intersection(chosen_genres)) > 0)]

    # Extraindo os gêneros e criando colunas binárias para cada gênero
    genres_matrix = movies_with_similar_genres['genres'].str.get_dummies(sep='|')

    # Criando uma matriz de filmes e gêneros
    movies_genre_matrix = pd.concat([movies_with_similar_genres[['movieId']], genres_matrix], axis=1).set_index('movieId')

    # Aplicando SVD com 2 componentes
    svd = TruncatedSVD(n_components=2, random_state=42)
    matrix_svd = svd.fit_transform(movies_genre_matrix)

    # Convertendo para DataFrame para fácil manipulação
    svd_df = pd.DataFrame(matrix_svd, index=movies_genre_matrix.index, columns=[f'Component {i+1}' for i in range(2)])

    # Exibindo a forma da matriz SVD
    print("Forma da matriz SVD:", svd_df.shape)

    # Obtendo o ID do filme escolhido
    chosen_movie_id = movies.loc[movies['title'] == chosen_movie, 'movieId'].values[0]

    # Calculando as distâncias euclidianas do filme escolhido para os outros filmes
    chosen_movie_vector = svd_df.loc[chosen_movie_id].values.reshape(1, -1)
    distances = euclidean_distances(svd_df, chosen_movie_vector).flatten()

    # Adicionando as distâncias ao DataFrame
    svd_df['distance_to_chosen'] = distances

    # Ordenando os filmes pela distância, para encontrar os mais próximos
    closest_movies = svd_df.sort_values(by='distance_to_chosen').head(6)  # Inclui o próprio filme escolhido
    closest_movie_ids = closest_movies.index

    # Exibindo os títulos dos filmes mais próximos
    closest_titles = movies[movies['movieId'].isin(closest_movie_ids)]
    print("Filmes mais próximos do escolhido:")
    print(closest_titles[['title', 'genres']])

    # Visualizando a redução de dimensionalidade
    plt.figure(figsize=(10, 6))
    plt.scatter(svd_df['Component 1'], svd_df['Component 2'], alpha=0.5)

    # Destacando o filme escolhido
    plt.scatter(svd_df.loc[chosen_movie_id, 'Component 1'], svd_df.loc[chosen_movie_id, 'Component 2'], color='red', label=chosen_movie, s=100)

    # Destacando os filmes mais próximos (excluindo o próprio filme escolhido)
    for movie_id in closest_movie_ids:
        if movie_id != chosen_movie_id:
            plt.scatter(svd_df.loc[movie_id, 'Component 1'], svd_df.loc[movie_id, 'Component 2'], color='blue', label=movies.loc[movies['movieId'] == movie_id, 'title'].values[0])

    plt.title('Redução de Dimensionalidade com SVD (Baseado em Gêneros)')
    plt.xlabel('Componente 1')
    plt.ylabel('Componente 2')
    plt.grid(True)
    plt.legend()
    plt.show()

else:
    print(f"O filme '{chosen_movie}' não foi encontrado no DataFrame.")
# Out:
# Forma da matriz SVD: (32406, 2)
# Filmes mais próximos do escolhido:
#                                     title  \
# 0                        Toy Story (1995)
# 53485   Tangled: Before Ever After (2017)
# 53494               Trolls Holiday (2017)
# 80253              Bunyan and Babe (2017)
# 85313       Mavka: The Forest Song (2023)
# 85629  The Super Mario Bros. Movie (2023)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 53485  Adventure|Animation|Children|Comedy|Fantasy
# 53494  Adventure|Animation|Children|Comedy|Fantasy
# 80253  Adventure|Animation|Children|Comedy|Fantasy
# 85313  Adventure|Animation|Children|Comedy|Fantasy
# 85629  Adventure|Animation|Children|Comedy|Fantasy
